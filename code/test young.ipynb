# %%
# step 2: initialize the cohort of newborn
def count_age(age, group):
    num = 0
    for person in group:
        if person.age == age:
            num += 1
            #group_out.remove(person)
            
    return num

# change_rate related transition     
# transition from unemp to emp (job finding rate), from emp to unemp (job separation rate)
# from retired to death (death rate), from newborn to young (birth rate) 
# delete population from the group each year
def del_pop(group, change_rate):
    for _ in range(math.ceil(float(len(group))*change_rate)):
        random_element = random.choice(group)
        group.remove(random_element)
        
    return group
            
# adding population to the group each year        
def add_pop(group, change_rate):
    for _ in range(math.ceil(float(len(group))*change_rate)):
        random_element = random.choice(group)
        group.append(random_element)
        
    return group

import random
import math
import itertools # join multiple lists
import matplotlib.pyplot as plt

# Parameters
ini_population = 1000
simulation_years = 50

birth_rate = 0.011 # assume only population 15 years and over reproduce 

death_rate = 0.01 # assume death only happens after senior with count_death = count_senior * death_rate
death_age = 80 #a simple alternative way for the senior is assume they die after 80 years old
retirement_age = 65

# Assumption 3: all population aging from 15 to 64 are in labor force and 
# participation_rate = count 15-64 / total population
ini_workforce_rate = 0.7 

ini_aging_rate = 0.1 # aging_rate = count 65 and over/ workforce
ini_unemployment_rate = 0.05

job_finding_rate = 0.563
job_separation_rate = 0.47

class Person:
    def __init__(self, age, employed):
        self.age = age
        self.employed = employed
    
    def update_age(self):
        self.age += 1
        
    def is_newborn(self):
        return self.age == 0
    
    def is_young(self):
        return self.age < 15
    
    def is_workforce(self):
        return 14 < self.age < 65
    
    def is_senior(self):
        return self.age >= retirement_age
    
    def is_dead(self):
        return self.age > 80
    
    def is_unemployed(self):
        return not self.employed
    
    def is_employed(self):
        return self.employed

# iniize workforce data
# Assumption 3: all agents in between 15-64 choose to work, that is, labor force participation is 100%
# then unemployment population + employment population = workforce
ini_workforce = ini_population * ini_workforce_rate # 700
ini_senior = ini_workforce * ini_aging_rate # 70
ini_unemp = ini_workforce * ini_unemployment_rate # 700*0.05=35
ini_young = ini_population - ini_workforce - ini_senior

population_coh = []

newborn_coh = []
young_coh = []
workforce_coh = []
senior_coh = []

unemp_coh = []
emp_coh = []

unem_rate = []

# iniize population
random.seed(1)
for i in range(ini_population):
    if i < ini_young:
        person = Person(age=random.randint(0,14), employed=False)
        young_coh.append(person)
    
    elif i < ini_young + ini_unemp:
        person = Person(age=random.randint(15,64), employed=False)
        unemp_coh.append(person)
        
    elif i < ini_young + ini_workforce:
        person = Person(age=random.randint(15,64), employed=True)
        emp_coh.append(person)
        
    else:
        person = Person(age=random.randint(65,80), employed=False)
        senior_coh.append(person)

ini_num_newborn = math.ceil((ini_workforce + ini_senior)*birth_rate)
for i in range(ini_num_newborn):
    person = Person(age=0, employed=False)
    newborn_coh.append(person)

workforce_coh = list(itertools.chain(unemp_coh, emp_coh))
cohorts = [[len(newborn_coh)], [len(young_coh)], [len(workforce_coh)], [len(senior_coh)]]
population_coh = list(itertools.chain(newborn_coh, young_coh, workforce_coh, senior_coh))

print(cohorts)
# Out:
# [[9], [230], [700], [70]]

# %%
# step 2: initialize the cohort of newborn
def count_age(age, group):
    num = 0
    for person in group:
        if person.age == age:
            num += 1
            #group_out.remove(person)
            
    return num

# change_rate related transition     
# transition from unemp to emp (job finding rate), from emp to unemp (job separation rate)
# from retired to death (death rate), from newborn to young (birth rate) 
# delete population from the group each year
def del_pop(group, change_rate):
    for _ in range(math.ceil(float(len(group))*change_rate)):
        random_element = random.choice(group)
        group.remove(random_element)
        
    return group
            
# adding population to the group each year        
def add_pop(group, change_rate):
    for _ in range(math.ceil(float(len(group))*change_rate)):
        random_element = random.choice(group)
        group.append(random_element)
        
    return group

import random
import math
import itertools # join multiple lists
import matplotlib.pyplot as plt

# Parameters
ini_population = 1000
simulation_years = 50

birth_rate = 0.011 # assume only population 15 years and over reproduce 

death_rate = 0.01 # assume death only happens after senior with count_death = count_senior * death_rate
death_age = 80 #a simple alternative way for the senior is assume they die after 80 years old
retirement_age = 65

# Assumption 3: all population aging from 15 to 64 are in labor force and 
# participation_rate = count 15-64 / total population
ini_workforce_rate = 0.7 

ini_aging_rate = 0.1 # aging_rate = count 65 and over/ workforce
ini_unemployment_rate = 0.05

job_finding_rate = 0.563
job_separation_rate = 0.47

class Person:
    def __init__(self, age, employed):
        self.age = age
        self.employed = employed
    
    def update_age(self):
        self.age += 1
        
    def is_newborn(self):
        return self.age == 0
    
    def is_young(self):
        return self.age < 15
    
    def is_workforce(self):
        return 14 < self.age < 65
    
    def is_senior(self):
        return self.age >= retirement_age
    
    def is_dead(self):
        return self.age > 80
    
    def is_unemployed(self):
        return not self.employed
    
    def is_employed(self):
        return self.employed

# iniize workforce data
# Assumption 3: all agents in between 15-64 choose to work, that is, labor force participation is 100%
# then unemployment population + employment population = workforce
ini_workforce = ini_population * ini_workforce_rate # 700
ini_senior = ini_workforce * ini_aging_rate # 70
ini_unemp = ini_workforce * ini_unemployment_rate # 700*0.05=35
ini_young = ini_population - ini_workforce - ini_senior

population_coh = []

newborn_coh = []
young_coh = []
workforce_coh = []
senior_coh = []

unemp_coh = []
emp_coh = []

unem_rate = []

# iniize population
random.seed(1)
for i in range(ini_population):
    if i < ini_young:
        person = Person(age=random.randint(0,14), employed=False)
        young_coh.append(person)
    
    elif i < ini_young + ini_unemp:
        person = Person(age=random.randint(15,64), employed=False)
        unemp_coh.append(person)
        
    elif i < ini_young + ini_workforce:
        person = Person(age=random.randint(15,64), employed=True)
        emp_coh.append(person)
        
    else:
        person = Person(age=random.randint(65,80), employed=False)
        senior_coh.append(person)

ini_num_newborn = math.ceil((ini_workforce + ini_senior)*birth_rate)
for i in range(ini_num_newborn):
    person = Person(age=0, employed=False)
    newborn_coh.append(person)

workforce_coh = list(itertools.chain(unemp_coh, emp_coh))
cohorts = [[len(newborn_coh)], [len(young_coh)], [len(workforce_coh)], [len(senior_coh)]]
population_coh = list(itertools.chain(newborn_coh, young_coh, workforce_coh, senior_coh))

print(cohorts)

# Simulation loop
random.seed(2)
n = simulation_years - 45
for year in range(n):
    young_this_year = 0
    workforce_this_year = 0
    senior_this_year = 0
    newborn_this_year = 0

    for person in population_coh:      
                
        if person.is_young():
            young_this_year += 1
        
        if person.is_workforce():
            workforce_this_year += 1
                    
        if person.is_senior():
            senior_this_year += 1
        
        newborn_this_year = math.ceil((senior_this_year + workforce_this_year) * birth_rate)    
        person.update_age()
            
    print('young at the beginning of the', year, 'th year: ', young_this_year)
    print('count_14 at the ', year, 'th year: ', count_age(14, young_coh))
    print('young at the end of the', year, 'th year: ', young_this_year+newborn_this_year)
    print('\n')
# Out:
# [[9], [230], [700], [70]]
# young at the beginning of the 0 th year:  239
# count_14 at the  0 th year:  20
# young at the end of the 0 th year:  248
#
#
# young at the beginning of the 1 th year:  224
# count_14 at the  1 th year:  20
# young at the end of the 1 th year:  233
#
#
# young at the beginning of the 2 th year:  204
# count_14 at the  2 th year:  14
# young at the end of the 2 th year:  213
#
#
# young at the beginning of the 3 th year:  184
# count_14 at the  3 th year:  14
# young at the end of the 3 th year:  194
#
#
# young at the beginning of the 4 th year:  170
# count_14 at the  4 th year:  15
# young at the end of the 4 th year:  180

# %%
#step 3 

# Simulation loop
random.seed(2)
n = simulation_years - 45
for year in range(n):
    young_this_year = 0
    workforce_this_year = 0
    senior_this_year = 0
    newborn_this_year = 0

    for person in population_coh:      
                
        if person.is_young():
            young_this_year += 1
        
        if person.is_workforce():
            workforce_this_year += 1
                    
        if person.is_senior():
            senior_this_year += 1
        
        #newborn_this_year = math.ceil((senior_this_year + workforce_this_year) * birth_rate)    
        person.update_age()

    print('young at the beginning of the', year, 'th year: ', young_this_year)
    print('count_14 at the ', year, 'th year: ', count_14)       
    #print('new born at the ', year, 'th year: ', newborn_this_year)
    print('young at the end of the', year, 'th year: ', young_this_year, '\n')
# Out:
# young at the beginning of the 0 th year:  0
# count_14 at the  0 th year:  15
# young at the end of the 0 th year:  0
#
# young at the beginning of the 1 th year:  0
# count_14 at the  1 th year:  15
# young at the end of the 1 th year:  0
#
# young at the beginning of the 2 th year:  0
# count_14 at the  2 th year:  15
# young at the end of the 2 th year:  0
#
# young at the beginning of the 3 th year:  0
# count_14 at the  3 th year:  15
# young at the end of the 3 th year:  0
#
# young at the beginning of the 4 th year:  0
# count_14 at the  4 th year:  15
# young at the end of the 4 th year:  0

# %%
# step 2: pop age update 
def count_age(age, group):
    num = 0
    for person in group:
        if person.age == age:
            num += 1
            #group_out.remove(person)
            
    return num

# change_rate related transition     
# transition from unemp to emp (job finding rate), from emp to unemp (job separation rate)
# from retired to death (death rate), from newborn to young (birth rate) 
# delete population from the group each year
def del_pop(group, change_rate):
    for _ in range(math.ceil(float(len(group))*change_rate)):
        random_element = random.choice(group)
        group.remove(random_element)
        
    return group
            
# adding population to the group each year        
def add_pop(group, change_rate):
    for _ in range(math.ceil(float(len(group))*change_rate)):
        random_element = random.choice(group)
        group.append(random_element)
        
    return group

import random
import math
import itertools # join multiple lists
import matplotlib.pyplot as plt

# Parameters
ini_population = 1000
simulation_years = 50

birth_rate = 0.011 # assume only population 15 years and over reproduce 

death_rate = 0.01 # assume death only happens after senior with count_death = count_senior * death_rate
death_age = 80 #a simple alternative way for the senior is assume they die after 80 years old
retirement_age = 65

# Assumption 3: all population aging from 15 to 64 are in labor force and 
# participation_rate = count 15-64 / total population
ini_workforce_rate = 0.7 

ini_aging_rate = 0.1 # aging_rate = count 65 and over/ workforce
ini_unemployment_rate = 0.05

job_finding_rate = 0.563
job_separation_rate = 0.47

class Person:
    def __init__(self, age, employed):
        self.age = age
        self.employed = employed
    
    def update_age(self):
        self.age += 1
        
    def is_newborn(self):
        return self.age == 0
    
    def is_young(self):
        return self.age < 15
    
    def is_senior(self):
        return self.age >= retirement_age
    
    def is_dead(self):
        return self.age > 80
    
    def is_unemployed(self):
        return not self.employed
    
    def is_employed(self):
        return self.employed

# iniize workforce data
# Assumption 3: all agents in between 15-64 choose to work, that is, labor force participation is 100%
# then unemployment population + employment population = workforce
ini_workforce = ini_population * ini_workforce_rate # 700
ini_senior = ini_workforce * ini_aging_rate # 70
ini_unemp = ini_workforce * ini_unemployment_rate # 700*0.05=35
ini_young = ini_population - ini_workforce - ini_senior

population_coh = []

newborn_coh = []
young_coh = []
workforce_coh = []
senior_coh = []

unemp_coh = []
emp_coh = []

unem_rate = []

# iniize population
random.seed(1)
for i in range(ini_population):
    if i < ini_young:
        person = Person(age=random.randint(0,14), employed=False)
        young_coh.append(person)
    
    elif i < ini_young + ini_unemp:
        person = Person(age=random.randint(15,64), employed=False)
        unemp_coh.append(person)
        
    elif i < ini_young + ini_workforce:
        person = Person(age=random.randint(15,64), employed=True)
        emp_coh.append(person)
        
    else:
        person = Person(age=random.randint(65,80), employed=False)
        senior_coh.append(person)

for i in range(ini_workforce + ini_senior):
    person = Person(age=0, employed=False)
    newborn_coh.append(person)

workforce_coh = list(itertools.chain(unemp_coh, emp_coh))
cohorts = [[newborn_coh], [len(young_coh)], [len(workforce_coh)], [len(senior_coh)]]
population_coh = list(itertools.chain(newborn_coh, young_coh, workforce_coh, senior_coh))

print(cohorts)

# Simulation loop
n = simulation_years - 45
for year in range(n):
    young_this_year = 0
    workforce_this_year = 0
    senior_this_year = 0
    newborn_this_year = 0

    for person in population_coh:      
                
        if person.is_young():
            young_this_year += 1
            
        #count_14 = count_age(14, young_coh)
        
        if 14 < person.age < 65:
            workforce_this_year += 1
        
            
        if person.is_senior():
            senior_this_year += 1
        
        newborn_this_year = math.ceil((senior_this_year + workforce_this_year) * birth_rate)    
        person.update_age()

    print('young at the beginning of the', year, 'th year: ', young_this_year)
    print('count_14 at the ', year, 'th year: ', count_14)       
    print('new born at the ', year, 'th year: ', newborn_this_year)
    print('young at the end of the', year, 'th year: ', young_this_year, '\n')
    #print('workforce at the ', year, 'th year: ', workforce_this_year)
    #print('senior at the ', year, 'th year: ', senior_this_year, '\n')
# Out:
# [[70], [230], [35], [665]]
# young at the beginning of the 0 th year:  230
# count_14 at the  0 th year:  20
# new born at the  0 th year:  9
# young at the end of the 0 th year:  219
#
# young at the beginning of the 1 th year:  215
# count_14 at the  1 th year:  20
# new born at the  1 th year:  9
# young at the end of the 1 th year:  204
#
# young at the beginning of the 2 th year:  195
# count_14 at the  2 th year:  14
# new born at the  2 th year:  9
# young at the end of the 2 th year:  190
#
# young at the beginning of the 3 th year:  175
# count_14 at the  3 th year:  14
# new born at the  3 th year:  10
# young at the end of the 3 th year:  171
#
# young at the beginning of the 4 th year:  161
# count_14 at the  4 th year:  15
# new born at the  4 th year:  10
# young at the end of the 4 th year:  156

# %%
    count_14 = group_out(14, young_coh)
    print('count_14 at the beginning of the', year, 'th year: ', count_14)
    
    count_64 = group_out(64, workforce_coh)
    print('count_64 at the beginning of the', year, 'th year: ', count_64)
    
    count_80 = group_out(80, senior_coh)
    print('count_80 at the beginning of the', year, 'th year: ', count_80)

# %%
person.update_age()

        if person.is_young():
            young_this_year += 1
            young_this_year += newborn_this_year
            
        if person.is_senior() and not person.is_dead():
            senior_this_year += 1
        

            
        if 14 < person.age < 65:
            if person.is_unemployed():
                unemp_this_year += 1
            else:
                emp_this_year += 1
        
    senior_this_year -= math.ceil(senior_this_year * death_rate)
    print('young at the beginning of the ', year, 'th year: ', young_this_year)

    
    young_this_year += newborn_this_year
    print('young at the end of the ', year, 'th year: ', young_this_year, '\n')
    
    my_list = [senior_this_year, young_this_year, unemp_this_year, emp_this_year]
    [cohorts[i].append(my_list[i]) for i in range(len(cohorts))]
    
print(cohorts)

# %%
# The most updated version debug 1 step 2: add del_pop and add_pop functions

import random
import math
import itertools # join multiple lists
import matplotlib.pyplot as plt

# Parameters
ini_population = 1000
simulation_years = 50

birth_rate = 0.011 # assume only population 15 years and over reproduce 

death_rate = 0.01 # assume death only happens after retired with count_death = count_senior * death_rate
death_age = 80 #a simple alternative way for the senior is assume they die after 80 years old
retirement_age = 65

# Assumption 3: all population aging from 15 to 64 are in labor force and 
# participation_rate = count 15-64 / total population
ini_workforce_rate = 0.7 

ini_aging_rate = 0.1 # aging_rate = count 65 and over/ workforce
ini_unemployment_rate = 0.05

job_finding_rate = 0.563
job_separation_rate = 0.47

class Person:
    def __init__(self, age, employed):
        self.age = age
        self.employed = employed
    
    def update_age(self):
        self.age += 1
        
    def is_newborn(self):
        return self.age == 0
    
    def is_young(self):
        return self.age < 15
    
    def is_retired(self):
        return self.age >= retirement_age
    
    def is_dead(self):
        return self.age > 80
    
    def is_unemployed(self):
        return not self.employed
    
    def is_employed(self):
        return self.employed

# iniize workforce data
# Assumption 3: all agents in between 15-64 choose to work, that is, labor force participation is 100%
# then unemployment population + employment population = workforce
ini_workforce = ini_population * ini_workforce_rate # 700
ini_senior = ini_workforce * ini_aging_rate # 70
ini_unemp = ini_workforce * ini_unemployment_rate # 700*0.05=35
ini_young = ini_population - ini_workforce - ini_senior

len_pop = [ini_young, ini_workforce, ini_senior]

population_coh = []
dependent_coh = []
senior_coh = []
young_coh = []
unemp_coh = []
emp_coh = []
unem_rate = []
# iniize population
for i in range(ini_population):
    if i < ini_young:
        person = Person(age=random.randint(0,14), employed=False)
        young_coh.append(person)
    
    elif i < ini_young + ini_unemp:
        person = Person(age=random.randint(15,64), employed=False)
        unemp_coh.append(person)
        
    elif i < ini_young + ini_workforce:
        person = Person(age=random.randint(15,64), employed=True)
        emp_coh.append(person)
        
    else:
        person = Person(age=random.randint(65,80), employed=False)
        senior_coh.append(person)
'''
    [count_14, young_coh] = group_out(14, young_coh)
    print('count_14: ', count_14)
    
'''
cohorts = [[len(senior_coh)], [len(young_coh)], [len(unemp_coh)], [len(emp_coh)]]
population_coh = list(itertools.chain(senior_coh, young_coh, unemp_coh, emp_coh))

#[print(person.age, person.employed) for person in senior_coh]
#print(cohorts)

# Simulation loop
n = simulation_years - 40
for year in range(1, n):
    [count_14, young_coh] = group_out(14, young_coh)
    print('count_14 last year: ', count_14)
    new_population = []
    
    young_this_year = 0
    retired_this_year = 0
    unemp_this_year = 0
    emp_this_year = 0
    
    for person in population_coh:
        
        person.update_age()

        if person.is_retired() and not person.is_dead():
            retired_this_year += 1
        
        if person.is_young():
            young_this_year += 1
            
        if 14 < person.age < 65:
            if person.is_unemployed():
                unemp_this_year += 1
            else:
                emp_this_year += 1
        
    retired_this_year -= math.ceil(retired_this_year * death_rate)
    print('young before at the ', year, 'th year: ', young_this_year)
    
    newborn_this_year = math.ceil((retired_this_year + unemp_this_year + emp_this_year) * birth_rate)
    print('new born at the ', year, 'th year: ', newborn_this_year)
    
    young_this_year += newborn_this_year
    print('young after at the ', year, 'th year: ', young_this_year, '\n')
    
    my_list = [retired_this_year, young_this_year, unemp_this_year, emp_this_year]
    [cohorts[i].append(my_list[i]) for i in range(len(cohorts))]
    
print(cohorts)
# Out:
# count_14 last year:  11
# young before at the  1 th year:  188
# new born at the  1 th year:  9
# young after at the  1 th year:  197
#
# count_14 last year:  11
# young before at the  2 th year:  176
# new born at the  2 th year:  9
# young after at the  2 th year:  185
#
# count_14 last year:  12
# young before at the  3 th year:  164
# new born at the  3 th year:  10
# young after at the  3 th year:  174
#
# count_14 last year:  13
# young before at the  4 th year:  151
# new born at the  4 th year:  10
# young after at the  4 th year:  161
#
# count_14 last year:  14
# young before at the  5 th year:  137
# new born at the  5 th year:  10
# young after at the  5 th year:  147
#
# count_14 last year:  15
# young before at the  6 th year:  122
# new born at the  6 th year:  10
# young after at the  6 th year:  132
#
# count_14 last year:  9
# young before at the  7 th year:  112
# new born at the  7 th year:  10
# young after at the  7 th year:  122
#
# count_14 last year:  7
# ...
