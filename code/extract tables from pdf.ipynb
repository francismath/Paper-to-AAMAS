# %%
import tabula

# Replace 'your_file.pdf' with the path to your PDF file
pdf_file = r'C:\Users\enmao\OneDrive - Carleton University\job\coop work permit\supporing documentation outside of Canada\0-checklist.pdf'

# Use tabula.read_pdf to extract tables from the PDF
tables = tabula.read_pdf(pdf_file, pages=1, multiple_tables=True)

# The tables variable will contain a list of DataFrame objects
# Loop through the tables to find the one you need
for i, table in enumerate(tables, start=1):
    # Print the table number (for reference)
    print(f"Table {i}:")
    print(table)

checklist = tables[0]    
checklist.to_csv('output.csv', index=False)
# Out:
# Got stderr: Sep. 01, 2023 9:01:31 A.M. org.apache.fontbox.ttf.CmapSubtable processSubtype14
# 警告: Format 14 cmap table is not supported and will be ignored
# Table 1:
#    Supporting Materials Checklist  Unnamed: 0  \
# 0                           Items        Name
# 1                               1         NaN
# 2                             NaN   Residency
# 3                               2         NaN
# 4                             NaN         NaN
# 5                               3         NaN
# 6                             NaN         NaN
# 7                               4         NaN
# 8                               5         NaN
# 9                               6         NaN
# 10                            NaN         NaN
# 11                              7         NaN
# 12                            NaN         NaN
# 13                              8         NaN
# 14                              9         NaN
# 15                            NaN  Employment
# ...
