# %%
# solve the system of nonlinear equations in aging labor market and unemployment 
# method 1: fsolve

import scipy
from scipy.optimize import fsolve
import numpy as np
import matplotlib.pyplot as plt

s = 0.6 # the bargaining power of the workers
psi_e = 0
psi_u = 0.5
psi_a = 1
n = 1
y_u = 0.4
y_a = 0.4

#pi = 1
bar_p = 0.1
c = 0.2
delta = 0.1

# let the matching function in labor market 
# m(u,v)=kappa*u**zeta*v**(1-zeta) 
# then q(theta) = m(u,v)/v = kappa*theta**(-zeta),f(theta) = m(u,v)/u = kappa*theta**(1-zeta) 

kappa = 0.5
zeta = 0.35

def equations(z):
    u, theta, bar_p = z
# use np.sign(a)*(np.abs(a))**(-zeta) to avoid Numpy not allowing fractional powers of negative numbers
    q = kappa*np.sign(theta)*(np.abs(theta)) ** (-zeta)
    f = theta*q
    b = (n-u)*(1+psi_e)+u*(1+psi_u)+a*(1+psi_a)
    w = (1-s)*y_u + s*pi
    
    return (c-q*(1-s)*(pi-y_u), 
            (n-u)*(1+psi_e)/b*(1-2*psi_e/(1+psi_e)*(n-u)/b
                              )*w/bar_p*(bar_p-c)
            +u*(1+psi_u)/b*(1-2*psi_u/(1+psi_u)*u/b
                              )*y_u/bar_p*(bar_p-c)
            +a*(1+psi_a)/b*(1-2*psi_a/(1+psi_a)*a/b
                              )*y_a/bar_p*(bar_p-c)
            -pi,
            u-n*(1-f)-(n-u)*delta
           )


unemp = []
price = []
tight_labor = []
net_profit = []
aging = []



for a in np.arange(0, 2, 0.01):
    # u, theta, pi=  fsolve(equations, (0.01, 1, 0.1))
    u, theta, bar_p=  fsolve(equations, (0.01, 1, 0.1))
    if u > 0 and u < 0.9:
        unemp.append(u)
        tight_labor.append(theta)
        #net_profit.append(pi)
        price.append(bar_p)
        aging.append(a)
                
        
#aging = np.arange(0.01, 2, 0.1)
plt.figure()
plt.subplot(311)
plt.plot(aging, unemp)
#plt.xticks(np.arange(min(aging), max(aging)+1, 0.2))
#plt.xlabel('Aged Dependency Ratio')
plt.ylabel('Unemployment Rate')

plt.subplot(312)
plt.plot(aging, tight_labor)
#plt.xlabel('Aged Dependency Ratio')
plt.ylabel('labor market tightness')

plt.subplot(313)
#plt.plot(aging, net_profit)
plt.plot(aging, price)
plt.xlabel('Aged Dependency Ratio')
#plt.ylabel('net profit')
plt.ylabel('price')
plt.xlim([0,2])

plt.savefig('aging vs unemp tightness and net profit.png')
#plt.savefig('aging vs unemp tightness and price.png')
plt.show()

# %%
# solve the system of nonlinear equations in aging labor market and unemployment 
# method 1: fsolve

import scipy
from scipy.optimize import fsolve
import numpy as np
import matplotlib.pyplot as plt

s = 0.6 # the bargaining power of the workers
psi_e = 0
psi_u = 0.5
psi_a = 1
n = 1
y_u = 0.4
y_a = 0.4
bar_p = 1
c = 0.2
delta = 0.1

# let the matching function in labor market 
# m(u,v)=kappa*u**zeta*v**(1-zeta) 
# then q(theta) = m(u,v)/v = kappa*theta**(-zeta),f(theta) = m(u,v)/u = kappa*theta**(1-zeta) 

kappa = 0.5
zeta = 0.35

def equations(p):
    u, theta, pi = p
# use np.sign(a)*(np.abs(a))**(-zeta) to avoid Numpy not allowing fractional powers of negative numbers
    q = kappa*np.sign(theta)*(np.abs(theta)) ** (-zeta)
    f = theta*q
    b = (n-u)*(1+psi_e)+u*(1+psi_u)+a*(1+psi_a)
    w = (1-s)*y_u + s*pi
    
    return (c-q*(1-s)*(pi-y_u), 
            (n-u)*(1+psi_e)/b*(1-2*psi_e/(1+psi_e)*(n-u)/b
                              )*w/bar_p*(bar_p-c)
            +u*(1+psi_u)/b*(1-2*psi_u/(1+psi_u)*(n-u)/b
                              )*y_u/bar_p*(bar_p-c)
            +a*(1+psi_a)/b*(1-2*psi_a/(1+psi_a)*(n-u)/b
                              )*y_a/bar_p*(bar_p-c)
            -pi,
            u-n*(1-f)-(n-u)*delta
           )


unemp = []
tight_labor = []
net_profit = []
aging = []


for a in np.arange(0, 2, 0.01):
    u, theta, pi=  fsolve(equations, (0.01, 1, 0.1))
    if u > 0 and u < 0.9:
        unemp.append(u)
        tight_labor.append(theta)
        net_profit.append(pi)
        aging.append(a)
                
        
#aging = np.arange(0.01, 2, 0.1)
plt.figure()
plt.subplot(311)
plt.plot(aging, unemp)
#plt.xticks(np.arange(min(aging), max(aging)+1, 0.2))
#plt.xlabel('Aged Dependency Ratio')
plt.ylabel('Unemployment Rate')

plt.subplot(312)
plt.plot(aging, tight_labor)
#plt.xlabel('Aged Dependency Ratio')
plt.ylabel('labor market tightness')

plt.subplot(313)
plt.plot(aging, net_profit)
plt.xlabel('Aged Dependency Ratio')
plt.ylabel('net profit')
plt.xlim([0,2])

plt.savefig('aging vs unemp tightness and net profit.png')
plt.show()

# %%
def q_theta(theta):
    return kappa*np.sign(theta)*(np.abs(theta)) ** (-zeta)

q_theta_value = q_theta(tight_labor)

plt.plot(tight_labor,q_theta_value)

# %%
len(tight_labor)
# pca
# LITERATURE REVIEW
# MATHEMATICA AND MATLAB
# Out:
# 13

# %%
#unemp

# %%
u = n(1-f(theta))+(n-u)delta
(1+delta)u = n(1-f(theta))
